# %%
import pandas as pd
dados = pd.read_csv("teste.csv")
dados
# Out:
#     Unnamed: 0  retweet_count  \
# 0            0            808
# 1            1             50
# 2            2            650
# 3            3            414
# 4            4             68
# 5            5           3604
# 6            6           3202
# 7            7             18
# 8            8            402
# 9            9            528
# 10          10            268
# 11          11             84
# 12          12            132
# 13          13             86
#
#                                                  text           track_name  \
# 0   デジタル時代の漫画の未来を切り開く：「マンガ図書館Z」が目指すこと https://t.co...  マンガ図書館Z -人気漫画が読み放題！
# 1   In this week's new sci-fi &amp; fantasy books:...    Green Riding Hood
# 2   6月２９日（土）放送予定の\n#NHKスペシャル  #東京ミラクル では\n#佐藤健 が\n...                  謎解き
# 3   【首都圏で電車でしか行けない駅は？】\n\n#佐藤健 がそんな謎の駅を探す！\n\nヒント ...                  謎解き
# 4   もともとこのカフェのことを知っていて、\nドラマを見ていた時に気づいたのですが…\nふたりと...                  謎解き
# ...
