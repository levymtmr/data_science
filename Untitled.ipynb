# %%
import pandas as pd
dados = pd.read_csv("AppleStore.csv")
dados_filtrados = pd.read_csv("arquivo.csv")
lista = []
for i in dados_filtrados.head(10)["track_name"]:
    lista.append(i)
teste = dados["track_name"].isin(lista)
retorno = dados[teste]
retorno
# Out:
#     Unnamed: 0         id                                         track_name  \
# 7            8  284035177                            Pandora - Music & Radio
# 18          20  284993459  Shazam - Discover music, artists, videos & lyrics
# 24          27  286799607                        Cleartune - Chromatic Tuner
# 28          32  288120394                                           TouchOSC
# 35          40  290638154          iHeartRadio – Free Music & Radio Stations
# 41          49  292738169  Deezer - Listen to your Favorite Music & Playl...
# 43          51  293523031                                   Sonos Controller
# 65          74  298206806                iReal Pro - Music Book & Play Along
# 66          75  298596830                                          NRJ Radio
# 87         100  304731501                    Tempo - Metronome with Setlists
#
#     size_bytes currency  price  rating_count_tot  rating_count_ver  \
# ...
